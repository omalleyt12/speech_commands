# %%
import features
import preprocessing as pp
import tensorflow as tf
from importlib import reload

# %%
f = tf.placeholder(tf.float32,[None,16000])

# %%
s = pp.tf_preprocess(f,f,tf.constant(False),tf.constant(False))
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /anaconda/envs/py35/lib/python3.5/site-packages/tensorflow/python/framework/common_shapes.py in _call_cpp_shape_fn_impl(op, input_tensors_needed, input_tensors_as_shapes_needed, require_shape_fn)
#     685           graph_def_version, node_def_str, input_shapes, input_tensors,
# --> 686           input_tensors_as_shapes, status)
#     687   except errors.InvalidArgumentError as err:
#
# /anaconda/envs/py35/lib/python3.5/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
#     474     # Delete the underlying status object from memory otherwise it stays alive
#
# ...

# %%
s.shape
# Out:
# TensorShape([Dimension(None), Dimension(16000)])

# %%
reload(pp)
# Out:
# <module 'preprocessing' from '/home/tom/notebooks/SpeechCommands/preprocessing.py'>
